# %%
import tensorflow as tf
import numpy as np
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Embedding, Dropout, TimeDistributed
from keras.layers import LSTM
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
import pandas as pd
import collections
import sqlite3
import re
import os
import sys

pd.set_option('display.max_colwidth', -1)
# Out:
# Using TensorFlow backend.

# %%
""" PARAMS """
#VOCAB_L = 20
DROPOUT = 0.60
HIDDEN  = 1080
BATCH   = 100
N_EPOCH = 50
STEP    = 15

# %%
sqlite_file = '../../data/database/deeplearning.sqlite'
table_name  = 'tweets'
cnxn = sqlite3.connect(sqlite_file)
q    ='SELECT * FROM {};'.format(table_name)
data = pd.read_sql_query(q, cnxn)

# %%
def strip_links(txt):
  txt = re.sub(r'(?:\w+|\@\w+|\#\w+)\.twitter\.com\/\w+', '', txt)
  return(re.sub(r'(?:http|ftp|https)://(?:[\w_-]+(?:(?:\.[\w_-]+)+))(?:[\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', '', txt))

def strip_whitespace(txt):
  txt = txt.strip(' ')
  return(re.sub(r' +', ' ', txt))

def strip_metachar(txt):
    return(re.sub(r"[^a-zA-Z0-9\-\@\#\.\, ]+", '', txt))

def strip_ats(txt):
    return(re.sub(r'(\@|\#)\w*', '', txt))

data['CleanText'] = data['Text'].apply(lambda t: strip_links(t))
data['CleanText'] = data['CleanText'].apply(lambda t: strip_whitespace(t))
data['CleanText'] = data['CleanText'].apply(lambda t: strip_metachar(t))
data['CleanText'] = data['CleanText'].apply(lambda t: strip_ats(t))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b36ad4ed0967> in <module>()
#      13     return(re.sub(r'(\@|\#)\w*', '', txt))
#      14
# ---> 15 data['CleanText'] = data['Text'].apply(lambda t: strip_links(t))
#      16 data['CleanText'] = data['CleanText'].apply(lambda t: strip_whitespace(t))
#      17 data['CleanText'] = data['CleanText'].apply(lambda t: strip_metachar(t))
#
# NameError: name 'data' is not defined

# %%
train = data.sample(frac=0.7, random_state=200)
val  = data.drop(train.index)
#test   = test.sample(frac=0.5, random_state=200)
#val  = test.drop(val.index)
train, val = train.CleanText.values, val.CleanText.values

# %%
np.savetxt('train.txt', train, fmt = '%s')
#np.savetxt('test.txt', test, fmt = '%s')
np.savetxt('val.txt', val, fmt = '%s')

# %%
def read_words(filename):
    with tf.gfile.GFile(filename, "r") as f:
        return f.read().replace("\n", "<eos>").split()
    
def build_vocab(filename):
    data = read_words(filename)
    counter = collections.Counter(data)
    count_pairs = sorted(counter.items(), key=lambda x: (-x[1], x[0]))
    words, _ = list(zip(*count_pairs))
    word_to_id = dict(zip(words, range(len(words))))
    return word_to_id

def file_to_word_ids(filename, word_to_id):
    data = read_words(filename)
    return [word_to_id[word] for word in data if word in word_to_id]

# %%
def load_data():
    # get the data paths
    train_path = 'train.txt'
    valid_path = 'val.txt'
    #test_path  = 'test.txt'

    # build the complete vocabulary, then convert text data to list of integers
    word_to_id = build_vocab(train_path)
    train_data = file_to_word_ids(train_path, word_to_id)
    valid_data = file_to_word_ids(valid_path, word_to_id)
    #test_data = file_to_word_ids(test_path, word_to_id)
    vocabulary = len(word_to_id)
    reversed_dictionary = dict(zip(word_to_id.values(), word_to_id.keys()))

    print(train_data[:5])
    print(word_to_id)
    print(vocabulary)
    print(" ".join([reversed_dictionary[x] for x in train_data[:10]]))
    return train_data, valid_data, vocabulary, reversed_dictionary

# %%
train_data, valid_data, vocabulary, reversed_dictionary = load_data()
# Out:
# [16, 9081, 75, 23, 958]
# {'the': 0, 'to': 1, 'of': 2, 'and': 3, 'in': 4, 'a': 5, 'for': 6, 'via': 7, 'is': 8, 'by': 9, 'on': 10, '-': 11, 'with': 12, 'are': 13, 'at': 14, '<eos>': 15, 'Data': 16, 'from': 17, ',': 18, 'more': 19, 'you': 20, 'that': 21, 'your': 22, 'The': 23, 'data': 24, 'be': 25, 'will': 26, '<eos>The': 27, 'an': 28, 'can': 29, 'this': 30, 'AI': 31, 'Read': 32, '.': 33, 'new': 34, 'it': 35, 'I': 36, 'about': 37, 'as': 38, 'how': 39, '<eos>How': 40, 'Learning': 41, 'our': 42, 'A': 43, 'have': 44, 'we': 45, 'here': 46, 'its': 47, '2018': 48, 'or': 49, 'their': 50, 'Infographic': 51, 'Science': 52, '<eos>What': 53, 'out': 54, 'all': 55, 'what': 56, 'business': 57, 'Cc': 58, 'has': 59, 'my': 60, 'not': 61, 'do': 62, 'To': 63, 'Your': 64, 'In': 65, 'future': 66, 'Digital': 67, 'More': 68, 'but': 69, 'one': 70, '10': 71, 'learning': 72, 'some': 73, 'Intelligence': 74, 'Is': 75, 'great': 76, 'most': 77, 'Business': 78, 'need': 79, 'up': 80, 'New': 81, '<eos>A': 82, 'Big': 83, 'know': 84, 'Industrial': 85, 'You': 86, 'Machine': 87, 'What': 88, 'world': 89, 'For': 90, 'Analytics': 91, 'How': 92, 'And': 93, 'using': 94, 'who': 95, 'big': 96, 'so': 97, 'use': 98, 'first': 99, 'get': 100, 'help': 101, 'article': 102, 'machine': 103, 'Content': 104, 'into': 105, 'work': 106, 'just': 107, 'make': 108, 'was': 109, 'Future': 110, 'This': 111, 'time': 112, '5': 113, 'Fourth': 114, 'With': 115, 'World': 116, 'than': 117, '<eos>Why': 118, 'IoT': 119, 'Link': 120, 'cc': 121, 'should': 122, 'Marketing': 123, 'companies': 124, 'like': 125, 'over': 126, 'It': 127, 'they': 128, '3': 129, 'between': 130, 'could': 131, 'digital': 132, 'many': 133, 'MT': 134, 'Revolution': 135, 'now': 136, 'w': 137, 'which': 138, 'Artificial': 139, 'By': 140, 'key': 141, '<eos>Top': 142, 'Deep': 143, 'de': 144, 'these': 145, 'us': 146, 'We': 147, 'way': 148, 'Will': 149, 'create': 150, 'see': 151, 'trends': 152, 'people': 153, '<eos>This': 154, 'Transformation': 155, 'Trends': 156, 'good': 157, 'if': 158, 'About': 159, 'Can': 160, 'Huawei': 161, 'Its': 162, 'London': 163, 'Of': 164, 'last': 165, 'next': 166, 'think': 167, 'industry': 168, '20': 169, 'Global': 170, 'best': 171, 'build': 172, 'look': 173, 'me': 174, 'today': 175, 'value': 176, 'ways': 177, 'Are': 178, 'Technology': 179, 'been': 180, 'building': 181, 'going': 182, 'much': 183, 'skills': 184, 'technology': 185, '2': 186, '<eos>Data': 187, 'billion': 188, 'why': 189, '2019': 190, 'Cloud': 191, 'does': 192, 'technologies': 193, 'Smart': 194, 'Ways': 195, 'change': 196, 'science': 197, 'Learn': 198, 'Social': 199, 'Top': 200, 'Use': 201, 'analytics': 202, 'intelligence': 203, 'where': 204, 'Most': 205, 'R': 206, 'few': 207, 'full': 208, 'global': 209, 'la': 210, 'other': 211, 'through': 212, 'want': 213, '1': 214, 'Best': 215, 'Tech': 216, 'across': 217, 'go': 218, 'no': 219, 'power': 220, 'working': 221, 'Enterprise': 222, 'Things': 223, 'learn': 224, 'there': 225, 'when': 226, '4': 227, 'Companies': 228, 'Industry': 229, 'Key': 230, 'around': 231, 'conversation': 232, 'models': 233, 'things': 234, 'top': 235, '<eos>6': 236, 'Internet': 237, 'mobile': 238, 'post': 239, 'still': 240, 'talk': 241, '...': 242, 'HT': 243, 'Innovation': 244, 'better': 245, 'needs': 246, 'take': 247, 'years': 248, '<eos>10': 249, 'From': 250, 'Google': 251, 'applications': 252, 'being': 253, 'customer': 254, 'deep': 255, 'only': 256, 'process': 257, 'steps': 258, 'team': 259, '4ir': 260, '<eos>AI': 261, 'HR': 262, 'Know': 263, 'Python': 264, 'already': 265, 'also': 266, '<eos>7': 267, '<eos>Check': 268, '<eos>New': 269, 'An': 270, 'Development': 271, 'Mobile': 272, 'Part': 273, 'am': 274, 'company': 275, 'development': 276, 'dont': 277, 'may': 278, 'open': 279, 'part': 280, 'set': 281, '...cc': 282, 'Make': 283, 'Update': 284, 'Why': 285, 'et': 286, 'find': 287, 'solutions': 288, 'transformation': 289, 'very': 290, '<eos>5': 291, '<eos>8': 292, 'Heres': 293, 'ML': 294, 'Meetup': 295, 'Services': 296, 'That': 297, 'Using': 298, 'age': 299, ' ...
# 15398
# Data Literacy Is The Biggest Challenge In Analytics Education -<eos>Why

# %%
class KerasBatchGenerator(object):

    def __init__(self, data, num_steps, batch_size, vocabulary, skip_step=5):
        self.data = data
        self.num_steps = num_steps
        self.batch_size = batch_size
        self.vocabulary = vocabulary
        # this will track the progress of the batches sequentially through the
        # data set - once the data reaches the end of the data set it will reset
        # back to zero
        self.current_idx = 0
        # skip_step is the number of words which will be skipped before the next
        # batch is skimmed from the data set
        self.skip_step = skip_step

    def generate(self):
        x = np.zeros((self.batch_size, self.num_steps))
        y = np.zeros((self.batch_size, self.num_steps, self.vocabulary))
        while True:
            for i in range(self.batch_size):
                if self.current_idx + self.num_steps >= len(self.data):
                    # reset the index back to the start of the data set
                    self.current_idx = 0
                x[i, :] = self.data[self.current_idx:self.current_idx + self.num_steps]
                temp_y = self.data[self.current_idx + 1:self.current_idx + self.num_steps + 1]
                # convert all of temp_y into a one hot representation
                y[i, :, :] = to_categorical(temp_y, num_classes=self.vocabulary)
                self.current_idx += self.skip_step
            yield x, y

# %%
train_data_generator = KerasBatchGenerator(train_data, STEP, BATCH, vocabulary,
                                           skip_step=STEP)
valid_data_generator = KerasBatchGenerator(valid_data, STEP, BATCH, vocabulary,
                                           skip_step=STEP)

# %%
model = Sequential()
model.add(Embedding(vocabulary, HIDDEN, input_length=STEP))
model.add(LSTM(HIDDEN, return_sequences=True))
model.add(LSTM(HIDDEN, return_sequences=True))
model.add(Dropout(DROPOUT))
model.add(TimeDistributed(Dense(vocabulary)))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])
checkpointer = ModelCheckpoint(filepath='model' + '/model-{epoch:02d}.hdf5', verbose=1)

# %%
model.fit_generator(train_data_generator.generate(), len(train_data)//(BATCH*STEP), N_EPOCH,
                        validation_data=valid_data_generator.generate(),
                        validation_steps=len(valid_data)//(BATCH*STEP), callbacks=[checkpointer])
# Out:
# Epoch 1/50
# 47/47 [==============================] - 41s 881ms/step - loss: 8.3821 - categorical_accuracy: 0.0250 - val_loss: 7.3488 - val_categorical_accuracy: 0.0295
#
# Epoch 00001: saving model to model/model-01.hdf5
# Epoch 2/50
# 47/47 [==============================] - 35s 747ms/step - loss: 7.8733 - categorical_accuracy: 0.0299 - val_loss: 7.3296 - val_categorical_accuracy: 0.0361
#
# Epoch 00002: saving model to model/model-02.hdf5
# Epoch 3/50
# 47/47 [==============================] - 35s 749ms/step - loss: 7.7629 - categorical_accuracy: 0.0312 - val_loss: 7.3048 - val_categorical_accuracy: 0.0335
#
# Epoch 00003: saving model to model/model-03.hdf5
# Epoch 4/50
# 47/47 [==============================] - 36s 763ms/step - loss: 7.6820 - categorical_accuracy: 0.0312 - val_loss: 7.3391 - val_categorical_accuracy: 0.0330
#
# Epoch 00004: saving model to model/model-04.hdf5
# Epoch 5/50
# 47/47 [==============================] - 35s 752ms/step - loss: 7.5791 - categorical_accuracy: 0.0314 - val_loss: 7.3745 - val_categorical_accuracy: 0.0361
#
# Epoch 00005: saving model to model/model-05.hdf5
# Epoch 6/50
# 47/47 [==============================] - 35s 753ms/step - loss: 7.5190 - categorical_accuracy: 0.0314 - val_loss: 7.3743 - val_categorical_accuracy: 0.0354
#
# Epoch 00006: saving model to model/model-06.hdf5
# Epoch 7/50
# 47/47 [==============================] - 35s 748ms/step - loss: 7.4413 - categorical_accuracy: 0.0324 - val_loss: 7.4512 - val_categorical_accuracy: 0.0358
#
# Epoch 00007: saving model to model/model-07.hdf5
# Epoch 8/50
# 47/47 [==============================] - 35s 751ms/step - loss: 7.3799 - categorical_accuracy: 0.0334 - val_loss: 7.4556 - val_categorical_accuracy: 0.0363
#
# Epoch 00008: saving model to model/model-08.hdf5
# Epoch 9/50
# 47/47 [==============================] - 35s 755ms/step - loss: 7.3433 - categorical_accuracy: 0.0342 - val_loss: 7.5666 - val_categorical_accuracy: 0.0372
#
# Epoch 00009: saving model to model/model-09.hdf5
# Epoch 10/50
# 47/47 [==============================] - 36s 756ms/step - loss: 7.3361 - categorical_accuracy: 0.0358 - val_loss: 7.5635 - val_categorical_accuracy: 0.0373
#
# Epoch 00010: saving model to model/model-10.hdf5
# Epoch 11/50
# 47/47 [==============================] - 35s 750ms/step - loss: 7.3079 - categorical_accuracy: 0.0362 - val_loss: 7.6412 - val_categorical_accuracy: 0.0354
#
# Epoch 00011: saving model to model/model-11.hdf5
# Epoch 12/50
# 47/47 [==============================] - 37s 788ms/step - loss: 7.2895 - categorical_accuracy: 0.0363 - val_loss: 7.6972 - val_categorical_accuracy: 0.0345
#
# Epoch 00012: saving model to model/model-12.hdf5
# Epoch 13/50
# 47/47 [==============================] - 34s 725ms/step - loss: 7.2426 - categorical_accuracy: 0.0386 - val_loss: 7.8245 - val_categorical_accuracy: 0.0329
#
# Epoch 00013: saving model to model/model-13.hdf5
# Epoch 14/50
# 47/47 [==============================] - 34s 716ms/step - loss: 7.2208 - categorical_accuracy: 0.0386 - val_loss: 7.7994 - val_categorical_accuracy: 0.0342
#
# Epoch 00014: saving model to model/model-14.hdf5
# Epoch 15/50
# 47/47 [==============================] - 34s 721ms/step - loss: 7.1781 - categorical_accuracy: 0.0406 - val_loss: 7.8161 - val_categorical_accuracy: 0.0348
#
# Epoch 00015: saving model to model/model-15.hdf5
# Epoch 16/50
# 47/47 [==============================] - 34s 723ms/step - loss: 7.1070 - categorical_accuracy: 0.0419 - val_loss: 7.9193 - val_categorical_accuracy: 0.0325
#
# Epoch 00016: saving model to model/model-16.hdf5
# Epoch 17/50
# 47/47 [==============================] - 33s 713ms/step - loss: 7.0056 - categorical_accuracy: 0.0433 - val_loss: 7.9165 - val_categorical_accuracy: 0.0323
#
# Epoch 00017: saving model to model/model-17.hdf5
# Epoch 18/50
# 47/47 [==============================] - 34s 726ms/step - loss: 6.9163 - categorical_accuracy: 0.0449 - val_loss: 7.9302 - val_categorical_accuracy: 0.0313
#
# Epoch 00018: saving model to model/model-18.hdf5
# Epoch 19/50
# 47/47 [==============================] - 34s 724ms/step - loss: 6.8069 - categorical_accuracy: 0.0470 - val_loss: 7.9858 - val_categorical_accuracy: 0.0318
#
# Epoch 00019: saving model to model/model-19.hdf5
# Epoch 20/50
# 47/47 [==============================] - 34s 731ms/step - loss: 6.7060 - categorical_accuracy: 0.0490 - val_loss: 8.0730 - val_categorical_accuracy: 0.0311
#
# Epoch 00020: saving model to model/model-20.hdf5
# Epoch 21/50
# 47/47 [==============================] - 36s 770ms/step - loss: 6.6260 - categorical_accuracy: 0.0504 - val_loss: 8.2073 - val_categorical_accuracy: 0.0289
#
# Epoch 00021: saving model to model/model-21.hdf5
# Epoch 22/50
# 47/47 [==============================] - 35s 746ms/step - loss: 6.5364 - categorical_accuracy: 0.0518 - val_loss: 8.2307 - val_categorical_accuracy: 0.0262
#
# Epoch 00022: saving model to model/model-22.hdf5
# Epoch 23/50
# 47/47 [==============================] - 35s 736ms/step - loss: 6.4265 - categorical_accuracy: 0.0560 - val_loss: 8.1745 - val_categorical_accuracy: 0.0289
#
# Epoch 00023: saving model to model/model-23.hdf5
# Epoch 24/50
# 47/47 [==============================] - 34s 723ms/step - loss: 6.2999 - categorical_accuracy: 0.0587 - val_loss: 8.2315 - val_categorical_accuracy: 0.0277
#
# Epoch 00024: saving model to model/model-24.hdf5
# Epoch 25/50
# 47/47 [==============================] - 36s 771ms/step - loss: 6.1835 - categorical_accuracy: 0.0627 - val_loss: 8.3318 - val_categorical_accuracy: 0.0212
#
# Epoch 00025: saving model to model/model-25.hdf5
# Epoch 26/50
# 47/47 [==============================] - 35s 742ms/step - loss: 6.0437 - categorical_accuracy: 0.0674 - val_loss: 8.4960 - val_categorical_accuracy: 0.0191
#
# Epoch 00026: saving model to model/model-26.hdf5
# Epoch 27/50
# 47/47 [==============================] - 35s 734ms/step - loss: 5.9023 - categorical_accuracy: 0.0747 - val_loss: 8.5765 - val_categorical_accuracy: 0.0210
#
# Epoch 00027: saving model to model/model-27.hdf5
# Epoch 28/50
# 47/47 [==============================] - 36s 761ms/step - loss: 5.7525 - categorical_accuracy: 0.0821 - val_loss: 8.5657 - val_categorical_accuracy: 0.0186
#
# Epoch 00028: saving model to model/model-28.hdf5
# Epoch 29/50
# 47/47 [==============================] - 35s 735ms/step - loss: 5.6084 - categorical_accuracy: 0.0907 - val_loss: 8.5875 - val_categorical_accuracy: 0.0187
#
# Epoch 00029: saving model to model/model-29.hdf5
# Epoch 30/50
# 47/47 [==============================] - 35s 753ms/step - loss: 5.4664 - categorical_accuracy: 0.1018 - val_loss: 8.7380 - val_categorical_accuracy: 0.0205
#
# Epoch 00030: saving model to model/model-30.hdf5
# Epoch 31/50
# 47/47 [==============================] - 39s 833ms/step - loss: 5.3513 - categorical_accuracy: 0.1131 - val_loss: 8.8275 - val_categorical_accuracy: 0.0179
#
# Epoch 00031: saving model to model/model-31.hdf5
# Epoch 32/50
# 47/47 [==============================] - 35s 748ms/step - loss: 5.2078 - categorical_accuracy: 0.1262 - val_loss: 8.8376 - val_categorical_accuracy: 0.0177
#
# Epoch 00032: saving model to model/model-32.hdf5
# Epoch 33/50
# 47/47 [==============================] - 35s 747ms/step - loss: 5.0545 - categorical_accuracy: 0.1425 - val_loss: 8.8150 - val_categorical_accuracy: 0.0219
#
# Epoch 00033: saving model to model/model-33.hdf5
# Epoch 34/50
# 47/47 [==============================] - 35s 745ms/step - loss: 4.8945 - categorical_accuracy: 0.1612 - val_loss: 8.8466 - val_categorical_accuracy: 0.0215
#
# Epoch 00034: saving model to model/model-34.hdf5
# Epoch 35/50
# 47/47 [==============================] - 35s 753ms/step - loss: 4.7703 - categorical_accuracy: 0.1761 - val_loss: 8.9655 - val_categorical_accuracy: 0.0161
#
# Epoch 00035: saving model to model/model-35.hdf5
# Epoch 36/50
# 47/47 [==============================] - 35s 753ms/step - loss: 4.5950 - categorical_accuracy: 0.1974 - val_loss: 9.0596 - val_categorical_accuracy: 0.0143
#
# Epoch 00036: saving model to model/model-36.hdf5
# Epoch 37/50
# 47/47 [==============================] - 35s 742ms/step - loss: 4.4634 - categorical_accuracy: 0.2168 - val_loss: 9.1794 - val_categorical_accuracy: 0.0163
#
# Epoch 00037: saving model to model/model-37.hdf5
# Epoch 38/50
# 47/47 [==============================] - 36s 771ms/step - loss: 4.3506 - categorical_accuracy: 0.2340 - val_loss: 9.1762 - val_categorical_accuracy: 0.0150
# Epoch 00038: saving model to model/model-38.hdf5
# Epoch 39/50
# 47/47 [==============================] - 36s 757ms/step - loss: 4.2325 - categorical_accuracy: 0.2497 - val_loss: 9.2875 - val_categorical_accuracy: 0.0153
#
# Epoch 00039: saving model to model/model-39.hdf5
# Epoch 40/50
# 47/47 [==============================] - 35s 752ms/step - loss: 4.1079 - categorical_accuracy: 0.2698 - val_loss: 9.3726 - val_categorical_accuracy: 0.0167
#
# Epoch 00040: saving model to model/model-40.hdf5
# Epoch 41/50
# 47/47 [==============================] - 36s 768ms/step - loss: 4.0139 - categorical_accuracy: 0.2828 - val_loss: 9.3413 - val_categorical_accuracy: 0.0161
#
# Epoch 00041: saving model to model/model-41.hdf5
# Epoch 42/50
# 47/47 [==============================] - 36s 767ms/step - loss: 3.8859 - categorical_accuracy: 0.3001 - val_loss: 9.4502 - val_categorical_accuracy: 0.0111
#
# Epoch 00042: saving model to model/model-42.hdf5
# Epoch 43/50
# 47/47 [==============================] - 37s 782ms/step - loss: 3.7809 - categorical_accuracy: 0.3180 - val_loss: 9.5126 - val_categorical_accuracy: 0.0096
#
# Epoch 00043: saving model to model/model-43.hdf5
# Epoch 44/50
# 47/47 [==============================] - 36s 767ms/step - loss: 3.6251 - categorical_accuracy: 0.3437 - val_loss: 9.5200 - val_categorical_accuracy: 0.0104
#
# Epoch 00044: saving model to model/model-44.hdf5
# Epoch 45/50
# 47/47 [==============================] - 35s 754ms/step - loss: 3.4843 - categorical_accuracy: 0.3661 - val_loss: 9.6099 - val_categorical_accuracy: 0.0109
#
# Epoch 00045: saving model to model/model-45.hdf5
# Epoch 46/50
# 47/47 [==============================] - 36s 760ms/step - loss: 3.3741 - categorical_accuracy: 0.3846 - val_loss: 9.7392 - val_categorical_accuracy: 0.0102
#
# Epoch 00046: saving model to model/model-46.hdf5
# Epoch 47/50
# 47/47 [==============================] - 37s 791ms/step - loss: 3.2147 - categorical_accuracy: 0.4078 - val_loss: 9.8870 - val_categorical_accuracy: 0.0100
#
# Epoch 00047: saving model to model/model-47.hdf5
# Epoch 48/50
# 47/47 [==============================] - 36s 768ms/step - loss: 3.1236 - categorical_accuracy: 0.4224 - val_loss: 9.8759 - val_categorical_accuracy: 0.0085
#
# Epoch 00048: saving model to model/model-48.hdf5
# Epoch 49/50
# 47/47 [==============================] - 36s 760ms/step - loss: 3.0055 - categorical_accuracy: 0.4405 - val_loss: 9.8731 - val_categorical_accuracy: 0.0080
#
# Epoch 00049: saving model to model/model-49.hdf5
# Epoch 50/50
# 47/47 [==============================] - 36s 768ms/step - loss: 2.9265 - categorical_accuracy: 0.4549 - val_loss: 9.8919 - val_categorical_accuracy: 0.0078
#
# Epoch 00050: saving model to model/model-50.hdf5

# %%
model = load_model('model' + "/model-15.hdf5")
dummy_iters = 40
example_training_generator = KerasBatchGenerator(train_data, STEP, 1, vocabulary,
                                                     skip_step=1)
print("Training data:")
for i in range(dummy_iters):
    dummy = next(example_training_generator.generate())
num_predict = 10
true_print_out = "Actual words: "
pred_print_out = "Predicted words: "
for i in range(num_predict):
    data = next(example_training_generator.generate())
    prediction = model.predict(data[0])
    predict_word = np.argmax(prediction[:, STEP-1, :])
    true_print_out += reversed_dictionary[train_data[STEP + dummy_iters + i]] + " "
    pred_print_out += reversed_dictionary[predict_word] + " "
print(true_print_out)
print(pred_print_out)
# Out:
# Training data:
# Actual words: he was reading my mind, literally..He described Long - the
# Predicted words: the of of the of the of the the of
